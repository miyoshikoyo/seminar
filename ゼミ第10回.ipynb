# %% [markdown]
# <a href="https://colab.research.google.com/github/miyoshikoyo/seminar/blob/main/%E3%82%BC%E3%83%9F%E7%AC%AC10%E5%9B%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("こんにちは")
print("私の名前は  ")
# Out:
# こんにちは

# %%
#sklearn というライブラリから、datasetsを利用する
from sklearn import datasets
#pandas パッケージを利用する
import pandas as pd
# load_boston でデータセットのサンプルを読み込む
dataset = datasets.load_boston()
#DataFrame に代入する
dataset2 = pd.DataFrame(dataset.data)
#列名を指定する
dataset2.columns=dataset.feature_names
#価格を取り出す
dataset3=pd.DataFrame(dataset.target)
dataset3
dataset2
#列名を指定する
dataset3.columns=['target']
#dataset2とdataset3をつなげる
dataset4=pd.concat([dataset3,dataset2],axis=1)
dataset4
# Out:
#      target     CRIM    ZN  INDUS  CHAS  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0      24.0  0.00632  18.0   2.31   0.0  ...  1.0  296.0     15.3  396.90   4.98
# 1      21.6  0.02731   0.0   7.07   0.0  ...  2.0  242.0     17.8  396.90   9.14
# 2      34.7  0.02729   0.0   7.07   0.0  ...  2.0  242.0     17.8  392.83   4.03
# 3      33.4  0.03237   0.0   2.18   0.0  ...  3.0  222.0     18.7  394.63   2.94
# 4      36.2  0.06905   0.0   2.18   0.0  ...  3.0  222.0     18.7  396.90   5.33
# ..      ...      ...   ...    ...   ...  ...  ...    ...      ...     ...    ...
# 501    22.4  0.06263   0.0  11.93   0.0  ...  1.0  273.0     21.0  391.99   9.67
# 502    20.6  0.04527   0.0  11.93   0.0  ...  1.0  273.0     21.0  396.90   9.08
# 503    23.9  0.06076   0.0  11.93   0.0  ...  1.0  273.0     21.0  396.90   5.64
# 504    22.0  0.10959   0.0  11.93   0.0  ...  1.0  273.0     21.0  393.45   6.48
# 505    11.9  0.04741   0.0  11.93   0.0  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %% [markdown]
# ボストンの住宅価格データ
#
# CRIM  人口一人あたりの犯罪率
#
# ZN    宅地比率
#
# INDUS 非小売業の面積比率
#
# CHAS  チャールズ側へと道がつながっているか否か
#
# NOX NOx濃度
#
# RM 住宅あたりの部屋数
#
# LSTAT 低階層人口の比率
#
# AGE 1940年以前に建てられた建物の割合
#
# DIS ボストンにおける5つの雇用中心地からの距離
#
# RAD 放射状幹線道路からの距離
#
# TAX 固定資産税率
#
# PTRATIO  教師あたりの生徒数
#
# B  黒人の比率
#
# MEDV  所有者が住む住宅の価格の中央地

# %%
dataset4.describe()
# Out:
#            target        CRIM          ZN  ...     PTRATIO           B       LSTAT
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean    22.532806    3.613524   11.363636  ...   18.455534  356.674032   12.653063
# std      9.197104    8.601545   23.322453  ...    2.164946   91.294864    7.141062
# min      5.000000    0.006320    0.000000  ...   12.600000    0.320000    1.730000
# 25%     17.025000    0.082045    0.000000  ...   17.400000  375.377500    6.950000
# 50%     21.200000    0.256510    0.000000  ...   19.050000  391.440000   11.360000
# 75%     25.000000    3.677083   12.500000  ...   20.200000  396.225000   16.955000
# max     50.000000   88.976200  100.000000  ...   22.000000  396.900000   37.970000
#
# [8 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(dataset4.target)
plt.ylabel('count')
plt.xlabel("target")
plt.grid(True)

# %%
import statsmodels.api as sm
x_list2 = dataset4.drop("target",1)
price= dataset4.target
x_list2
model =sm.OLS(price, sm.add_constant(x_list2))
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     108.1
# Date:                Thu, 17 Jun 2021   Prob (F-statistic):          6.72e-135
# Time:                        00:53:18   Log-Likelihood:                -1498.8
# No. Observations:                 506   AIC:                             3026.
# Df Residuals:                     492   BIC:                             3085.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.4595      5.103      7.144      0.000      26.432      46.487
# ...
